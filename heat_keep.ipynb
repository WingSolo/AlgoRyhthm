# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./data/data.csv', encoding='cp949')
df.head()
# Out:
#                TAG_MIN    배정번호  건조 1존 OP  건조 2존 OP  건조로 온도 1 Zone  \
# 0  2022-01-03 11:22:07  102410   75.6648   30.0155            NaN
# 1  2022-01-03 11:22:08  102410   75.6706   32.2732            NaN
# 2  2022-01-03 11:22:09  102410   75.6776   32.1592        98.8533
# 3  2022-01-03 11:22:11  102410   75.8656   30.8312        98.7918
# 4  2022-01-03 11:22:12  102410   73.6468   29.5274        98.7918
#
#    건조로 온도 2 Zone      세정기   소입1존 OP  소입2존 OP   소입3존 OP  ...  소입로 온도 2 Zone  \
# 0            NaN  68.4386  72.84030  59.7862  51.71690  ...        859.854
# 1            NaN  68.4386  78.44150  61.6286  50.44530  ...        859.780
# 2       99.14600  68.4386  78.10990  61.5414  52.01960  ...        859.780
# 3       99.17675  68.4999  77.50725  60.6663  52.69425  ...        859.842
# 4       99.20750  68.4386  76.02620  61.1634  51.69150  ...        859.791
#
#    소입로 온도 3 Zone  소입로 온도 4 Zone  솔트 1존 OP  솔트 2존 OP  솔트 슬러지 제거  \
# 0            NaN            NaN       NaN       NaN    321.275
# 1        860.044        859.786   73.0028       NaN    321.275
# 2        859.981        859.724   73.0028   60.3137    321.275
# 3        859.950        859.599   74.1009   60.5882    321.275
# 4        859.991        859.731   72.9029   60.2801    321.275
#
#    솔트 컨베이어 온도 1 Zone  솔트 컨베이어 온도 2 Zone  솔트조 온도 1 Zone  솔트조 온도 2 Zone
# 0                NaN                NaN            NaN            NaN
# 1            294.658            272.538        328.734        328.865
# 2            294.658            272.538        328.734        328.805
# 3            294.719            272.538        328.674        328.865
# 4            294.721            272.599        328.740        328.808
#
# [5 rows x 24 columns]

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
df.describe()
# Out:
#                 배정번호       건조 1존 OP       건조 2존 OP  건조로 온도 1 Zone  \
# count  345390.000000  345390.000000  345390.000000  345371.000000
# mean   105161.010200      72.793790      21.891918     100.000486
# std      1874.611955       2.961294       2.693991       0.396102
# min    102410.000000      52.981600       5.022410      97.728500
# 25%    103719.000000      71.453800      20.657800      99.833100
# 50%    105072.000000      73.051800      22.125900     100.003000
# 75%    106293.000000      74.567600      23.515800     100.174000
# max    108503.000000      84.591100      35.267700     102.076000
#
#        건조로 온도 2 Zone            세정기        소입1존 OP        소입2존 OP  \
# count  345367.000000  345386.000000  345136.000000  345390.000000
# mean      100.015480      67.543662      75.455289      46.748554
# std         0.284776       1.852949      19.980997       3.868429
# min        98.181000      60.624400       0.001077      33.955200
# 25%        99.900400      66.092800      69.512075      44.738400
# 50%       100.009000      67.236900      78.503900      46.201800
# 75%       100.118000      69.012100      87.086525      47.825000
# max       101.576000      71.490100     100.000000      66.040800
#
#              소입3존 OP        소입4존 OP  ...  소입로 온도 2 Zone  소입로 온도 3 Zone  \
# count  345390.000000  345390.000000  ...  345378.000000  345375.000000
# mean       50.297656      69.702672  ...     860.001237     860.000901
# std         1.894485       2.186086  ...       0.356628       0.245932
# min        36.712500      56.282400  ...     858.075000     858.608000
# 25%        49.190400      68.363600  ...     859.790000     859.850000
# 50%        50.392600      69.666000  ...     859.993000     859.999000
# 75%        51.549800      70.935200  ...     860.200000     860.153000
# max        59.364600      82.736000  ...     862.046000     861.136000
#
#        소입로 온도 4 Zone       솔트 1존 OP       솔트 2존 OP      솔트 슬러지 제거  \
# count  345374.000000  345370.000000  345373.000000  345372.000000
# mean      860.000223      66.052616      56.020924     329.980841
# std         0.356041       2.660639       2.180467       6.744774
# min       857.992000      56.194800      50.732000     318.593000
# 25%       859.843000      64.325400      54.364100     324.239000
# 50%       859.998000      65.815600      55.428400     329.838000
# 75%       860.148000      67.468000      57.592300     335.684000
# max       862.125000      83.567400      67.509500     341.884000
#
#        솔트 컨베이어 온도 1 Zone  솔트 컨베이어 온도 2 Zone  솔트조 온도 1 Zone  솔트조 온도 2 Zone
# count      345384.000000      345377.000000  345368.000000  345373.000000
# mean          282.872484         279.280458     330.289581     330.510025
# std             9.417347           6.455640       1.518338       1.571556
# min           266.230000         267.842000     328.161000     328.073000
# 25%           273.648000         273.039000     329.055000     329.167000
# 50%           283.348000         279.322000     329.211000     329.557000
# 75%           292.154000         285.522000     332.146000     332.426000
# max           297.002000         290.651000     332.591000     332.749000
#
# [8 rows x 23 columns]

# %%
df.dtypes
# Out:
# TAG_MIN               object
# 배정번호                   int64
# 건조 1존 OP             float64
# 건조 2존 OP             float64
# 건조로 온도 1 Zone        float64
# 건조로 온도 2 Zone        float64
# 세정기                  float64
# 소입1존 OP              float64
# 소입2존 OP              float64
# 소입3존 OP              float64
# 소입4존 OP              float64
# 소입로 CP 값             float64
# 소입로 CP 모니터 값         float64
# 소입로 온도 1 Zone        float64
# 소입로 온도 2 Zone        float64
# 소입로 온도 3 Zone        float64
# 소입로 온도 4 Zone        float64
# 솔트 1존 OP             float64
# 솔트 2존 OP             float64
# 솔트 슬러지 제거            float64
# 솔트 컨베이어 온도 1 Zone    float64
# 솔트 컨베이어 온도 2 Zone    float64
# 솔트조 온도 1 Zone        float64
# 솔트조 온도 2 Zone        float64
# dtype: object

# %%
df['TAG_MIN']=pd.to_datetime(df.TAG_MIN, format='%Y-%m-%d %H:%M:%S')

# %%
df.dtypes
# Out:
# TAG_MIN              datetime64[ns]
# 배정번호                          int64
# 건조 1존 OP                    float64
# 건조 2존 OP                    float64
# 건조로 온도 1 Zone               float64
# 건조로 온도 2 Zone               float64
# 세정기                         float64
# 소입1존 OP                     float64
# 소입2존 OP                     float64
# 소입3존 OP                     float64
# 소입4존 OP                     float64
# 소입로 CP 값                    float64
# 소입로 CP 모니터 값                float64
# 소입로 온도 1 Zone               float64
# 소입로 온도 2 Zone               float64
# 소입로 온도 3 Zone               float64
# 소입로 온도 4 Zone               float64
# 솔트 1존 OP                    float64
# 솔트 2존 OP                    float64
# 솔트 슬러지 제거                   float64
# 솔트 컨베이어 온도 1 Zone           float64
# 솔트 컨베이어 온도 2 Zone           float64
# 솔트조 온도 1 Zone               float64
# 솔트조 온도 2 Zone               float64
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.plot(df[['소입로 온도 1 Zone']])
plt.xlabel('index')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %%
df.isnull().sum()
# Out:
# TAG_MIN                0
# 배정번호                   0
# 건조 1존 OP               0
# 건조 2존 OP               0
# 건조로 온도 1 Zone         19
# 건조로 온도 2 Zone         23
# 세정기                    4
# 소입1존 OP              254
# 소입2존 OP                0
# 소입3존 OP                0
# 소입4존 OP                0
# 소입로 CP 값               0
# 소입로 CP 모니터 값          13
# 소입로 온도 1 Zone          5
# 소입로 온도 2 Zone         12
# 소입로 온도 3 Zone         15
# 소입로 온도 4 Zone         16
# 솔트 1존 OP              20
# 솔트 2존 OP              17
# 솔트 슬러지 제거             18
# 솔트 컨베이어 온도 1 Zone      6
# 솔트 컨베이어 온도 2 Zone     13
# 솔트조 온도 1 Zone         22
# 솔트조 온도 2 Zone         17
# dtype: int64

# %%
df = df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# TAG_MIN              0
# 배정번호                 0
# 건조 1존 OP             0
# 건조 2존 OP             0
# 건조로 온도 1 Zone        0
# 건조로 온도 2 Zone        0
# 세정기                  0
# 소입1존 OP              0
# 소입2존 OP              0
# 소입3존 OP              0
# 소입4존 OP              0
# 소입로 CP 값             0
# 소입로 CP 모니터 값         0
# 소입로 온도 1 Zone        0
# 소입로 온도 2 Zone        0
# 소입로 온도 3 Zone        0
# 소입로 온도 4 Zone        0
# 솔트 1존 OP             0
# 솔트 2존 OP             0
# 솔트 슬러지 제거            0
# 솔트 컨베이어 온도 1 Zone    0
# 솔트 컨베이어 온도 2 Zone    0
# 솔트조 온도 1 Zone        0
# 솔트조 온도 2 Zone        0
# dtype: int64

# %%
for col in df.columns:
    print(col, ':', len(df[col].value_counts()))
# Out:
# TAG_MIN : 345390
# 배정번호 : 14
# 건조 1존 OP : 110041
# 건조 2존 OP : 104879
# 건조로 온도 1 Zone : 10113
# 건조로 온도 2 Zone : 7034
# 세정기 : 33799
# 소입1존 OP : 222103
# 소입2존 OP : 114874
# 소입3존 OP : 85995
# 소입4존 OP : 95602
# 소입로 CP 값 : 35759
# 소입로 CP 모니터 값 : 3351
# 소입로 온도 1 Zone : 15280
# 소입로 온도 2 Zone : 3393
# 소입로 온도 3 Zone : 2464
# 소입로 온도 4 Zone : 3901
# 솔트 1존 OP : 20234
# 솔트 2존 OP : 19482
# 솔트 슬러지 제거 : 20918
# 솔트 컨베이어 온도 1 Zone : 30038
# 솔트 컨베이어 온도 2 Zone : 21676
# 솔트조 온도 1 Zone : 2405
# 솔트조 온도 2 Zone : 2733

# %%
import matplotlib
import matplotlib.font_manager as fm
plt.rcParams['font.size'] =20
plt.rcParams['font.family']='Malgun Gothic'
path = 'C:\\WINDOWS\\Fonts\\malgunbd.ttf'
font_name = fm.FontProperties(fname=path, size=20).get_name()
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns

# %%
plt.figure(figsize=(25,15))
target_cor = df.corr().loc[['건조 1존 OP', '건조 2존 OP', '건조로 온도 1 Zone', 
                             '건조로 온도 2 Zone', '세정기', '소입1존 OP', '소입2존 OP', '소입3존 OP', '소입4존 OP', 
                             '소입로 CP 값', '소입로 CP 모니터 값', '소입로 온도 1 Zone', '소입로 온도 2 Zone', 
                             '소입로 온도 3 Zone', '소입로 온도 4 Zone', '솔트 1존 OP', '솔트 2존 OP', 
                             '솔트 슬러지 제거','솔트 컨베이어 온도 1 Zone', '솔트 컨베이어 온도 2 Zone', 
                             '솔트조 온도 1 Zone', '솔트조 온도 2 Zone']]
sns.heatmap(target_cor,annot = True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
df.drop(['소입로 CP 모니터 값', '건조 1존 OP', '소입1존 OP', 'TAG_MIN', '배정번호'], axis=1, inplace=True)

# %%
df['이상치개수'] = 0
for col in df.columns:
    thirdq, firstq = df[col].quantile(0.75), df[col].quantile(0.25)
    interquartilerange = 1.5*(thirdq-firstq)
    outlierhigh, outlierlow = interquartilerange+thirdq, firstq-interquartilerange
    for i in df.index:
        if df[col][i] > outlierhigh or df[col][i] < outlierlow :
            df['이상치개수'][i] += 1

df.head()
# Out:
#    건조 2존 OP  건조로 온도 1 Zone  건조로 온도 2 Zone      세정기  소입2존 OP   소입3존 OP  \
# 0   30.0155     100.000486      100.01548  68.4386  59.7862  51.71690
# 1   32.2732     100.000486      100.01548  68.4386  61.6286  50.44530
# 2   32.1592      98.853300       99.14600  68.4386  61.5414  52.01960
# 3   30.8312      98.791800       99.17675  68.4999  60.6663  52.69425
# 4   29.5274      98.791800       99.20750  68.4386  61.1634  51.69150
#
#    소입4존 OP  소입로 CP 값  소입로 온도 1 Zone  소입로 온도 2 Zone  소입로 온도 3 Zone  \
# 0  71.8405  0.450421      859.56252        859.854     860.000901
# 1  70.5198  0.450356      860.33800        859.780     860.044000
# 2  72.0384  0.450341      860.33800        859.780     859.981000
# 3  73.4815  0.450201      860.33800        859.842     859.950000
# 4  71.6093  0.450235      860.35100        859.791     859.991000
#
#    소입로 온도 4 Zone   솔트 1존 OP   솔트 2존 OP  솔트 슬러지 제거  솔트 컨베이어 온도 1 Zone  \
# 0     860.000223  66.052616  56.020924    321.275         282.872484
# 1     859.786000  73.002800  56.020924    321.275         294.658000
# 2     859.724000  73.002800  60.313700    321.275         294.658000
# 3     859.599000  74.100900  60.588200    321.275         294.719000
# 4     859.731000  72.902900  60.280100    321.275         294.721000
#
#    솔트 컨베이어 온도 2 Zone  솔트조 온도 1 Zone  솔트조 온도 2 Zone  이상치개수
# 0         279.280458     330.289581     330.510025      2
# 1         272.538000     328.734000     328.865000      4
# 2         272.538000     328.734000     328.805000      6
# 3         272.538000     328.674000     328.865000      6
# 4         272.599000     328.740000     328.808000      6

# %%
df['이상치개수'].value_counts()
# Out:
# 이상치개수
# 0     223256
# 1      61618
# 2      30329
# 4      16742
# 5       8357
# 6       3384
# 7       1141
# 8        506
# 9         52
# 10         5
# Name: count, dtype: int64

# %%
df['설비 이상신호'] = np.where(df['이상치개수'] < 9, 0, 1)

df['설비 이상신호'].value_counts()
# Out:
# 설비 이상신호
# 0    345333
# 1        57
# Name: count, dtype: int64

# %%
normal = df.loc[df['설비 이상신호'] ==0]
abnormal = df.loc[df['설비 이상신호'] ==1]

print('정상 데이터: ', len(normal))
print('설비이상 데이터: ', len(abnormal))
# Out:
# 정상 데이터:  345333
# 설비이상 데이터:  57

# %%
normal.drop(columns='이상치개수', inplace=True)
abnormal.drop(columns='이상치개수', inplace=True)

# %%
from sklearn.model_selection import train_test_split
train_Y, test_Y = train_test_split(normal, test_size=0.3, random_state=1)
print('학습 데이터셋 개수: ', len(train_Y))
print('테스트 데이터셋 개수: ', len(test_Y))
# Out:
# 학습 데이터셋 개수:  241733
# 테스트 데이터셋 개수:  103600

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
normal_train_scaled=scaler.fit_transform(train_Y.iloc[:,:-1])
X_normal_train = pd.DataFrame(data=normal_train_scaled, index=train_Y.iloc[:,:-1].index, columns=train_Y.iloc[:,:-1].columns)
y_normal_train = train_Y.iloc[:,-1]
train_Y_normal = pd.concat([X_normal_train, y_normal_train],axis=1)

# %%
normal_test_scaled=scaler.transform(test_Y.iloc[:,:-1])
X_normal_test = pd.DataFrame(data=normal_test_scaled, index=test_Y.iloc[:,:-1].index, columns=test_Y.iloc[:,:-1].columns)
y_normal_test = test_Y.iloc[:, -1]
test_Y_normal = pd.concat([X_normal_test, y_normal_test], axis=1)

# %%
abnormal_test_scaled = scaler.transform(abnormal.iloc[:,:-1])
X_abnormal_test = pd.DataFrame(data=abnormal_test_scaled, index=abnormal.iloc[:,:-1].index, columns = abnormal.iloc[:,:-1].columns)
y_abnormal_test = abnormal.iloc[:,-1]
abnormal_data = pd.concat([X_abnormal_test, y_abnormal_test],axis=1)

# %%
import tensorflow as tf
tf.random.set_seed(1)
from keras.layers import Dense
from keras.models import Sequential

# %%
model_encoder=Sequential([
    Dense(15, activation = "relu"),
    Dense(10, activation = "relu"),
    Dense(5, activation = "relu")
])
model_decoder=Sequential([
    Dense(10, activation = "relu", input_shape=[5]),
    Dense(15, activation = "relu"),
    Dense(X_normal_train.shape[1], activation="relu")
])
AE_model=Sequential([model_encoder, model_decoder])

# %%
from tensorflow.keras.optimizers import Adam
AE_model.compile(loss="mse", optimizer=Adam(learning_rate=0.001))

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model_path = './model/{epoch:02d}-{val_loss:.4f}.hdf5'

history=AE_model.fit(X_normal_train, X_normal_train, batch_size=32, epochs=100, validation_split=0.2, 
                     callbacks=[EarlyStopping(monitor="val_loss", patience=10, mode="min"), 
                                ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=0, save_best_only=True)])
# Out:
# Epoch 1/100
# 6044/6044 [==============================] - 5s 779us/step - loss: 0.0720 - val_loss: 0.0661
# Epoch 2/100
# 6044/6044 [==============================] - 5s 764us/step - loss: 0.0479 - val_loss: 0.0381
# Epoch 3/100
# 6044/6044 [==============================] - 5s 762us/step - loss: 0.0379 - val_loss: 0.0377
# Epoch 4/100
# 6044/6044 [==============================] - 5s 764us/step - loss: 0.0377 - val_loss: 0.0376
# Epoch 5/100
# 6044/6044 [==============================] - 5s 758us/step - loss: 0.0375 - val_loss: 0.0370
# Epoch 6/100
# 6044/6044 [==============================] - 5s 759us/step - loss: 0.0360 - val_loss: 0.0351
# Epoch 7/100
# 6044/6044 [==============================] - 5s 750us/step - loss: 0.0351 - val_loss: 0.0349
# Epoch 8/100
# 6044/6044 [==============================] - 5s 756us/step - loss: 0.0350 - val_loss: 0.0351
# Epoch 9/100
# 6044/6044 [==============================] - 5s 756us/step - loss: 0.0350 - val_loss: 0.0348
# Epoch 10/100
# 6044/6044 [==============================] - 5s 757us/step - loss: 0.0348 - val_loss: 0.0346
# Epoch 11/100
# 6044/6044 [==============================] - 5s 770us/step - loss: 0.0349 - val_loss: 0.0346
# Epoch 12/100
# 6044/6044 [==============================] - 5s 755us/step - loss: 0.0283 - val_loss: 0.0262
# Epoch 13/100
# 6044/6044 [==============================] - 5s 746us/step - loss: 0.0266 - val_loss: 0.0264
# Epoch 14/100
# 6044/6044 [==============================] - 5s 757us/step - loss: 0.0264 - val_loss: 0.0262
# Epoch 15/100
# 6044/6044 [==============================] - 5s 754us/step - loss: 0.0263 - val_loss: 0.0262
# Epoch 16/100
# 6044/6044 [==============================] - 5s 745us/step - loss: 0.0263 - val_loss: 0.0263
# Epoch 17/100
# 6044/6044 [==============================] - 5s 752us/step - loss: 0.0263 - val_loss: 0.0262
# Epoch 18/100
# 6044/6044 [==============================] - 5s 749us/step - loss: 0.0262 - val_loss: 0.0261
# Epoch 19/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0192 - val_loss: 0.0081
# Epoch 20/100
# 6044/6044 [==============================] - 5s 754us/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 21/100
# 6044/6044 [==============================] - 5s 757us/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 22/100
# 6044/6044 [==============================] - 5s 748us/step - loss: 0.0080 - val_loss: 0.0082
# Epoch 23/100
# 6044/6044 [==============================] - 5s 750us/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 24/100
# 6044/6044 [==============================] - 5s 752us/step - loss: 0.0080 - val_loss: 0.0076
# Epoch 25/100
# 6044/6044 [==============================] - 5s 745us/step - loss: 0.0077 - val_loss: 0.0087
# Epoch 26/100
# 6044/6044 [==============================] - 5s 763us/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 27/100
# 6044/6044 [==============================] - 5s 759us/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 28/100
# 6044/6044 [==============================] - 4s 743us/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 29/100
# 6044/6044 [==============================] - 5s 748us/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 30/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0077 - val_loss: 0.0088
# Epoch 31/100
# 6044/6044 [==============================] - 5s 756us/step - loss: 0.0079 - val_loss: 0.0074
# Epoch 32/100
# 6044/6044 [==============================] - 5s 748us/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 33/100
# 6044/6044 [==============================] - 4s 743us/step - loss: 0.0075 - val_loss: 0.0077
# Epoch 34/100
# 6044/6044 [==============================] - 5s 746us/step - loss: 0.0077 - val_loss: 0.0083
# Epoch 35/100
# 6044/6044 [==============================] - 5s 748us/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 36/100
# 6044/6044 [==============================] - 4s 744us/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 37/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 38/100
# 6044/6044 [==============================] - 5s 757us/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 39/100
# 6044/6044 [==============================] - 5s 750us/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 40/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0072 - val_loss: 0.0071
# Epoch 41/100
# 6044/6044 [==============================] - 5s 752us/step - loss: 0.0073 - val_loss: 0.0076
# Epoch 42/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0077 - val_loss: 0.0073
# Epoch 43/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 44/100
# 6044/6044 [==============================] - 5s 746us/step - loss: 0.0072 - val_loss: 0.0071
# Epoch 45/100
# 6044/6044 [==============================] - 5s 750us/step - loss: 0.0072 - val_loss: 0.0071
# Epoch 46/100
# 6044/6044 [==============================] - 5s 749us/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 47/100
# 6044/6044 [==============================] - 5s 745us/step - loss: 0.0072 - val_loss: 0.0071
# Epoch 48/100
# 6044/6044 [==============================] - 5s 745us/step - loss: 0.0073 - val_loss: 0.0082
# Epoch 49/100
# 6044/6044 [==============================] - 5s 745us/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 50/100
# 6044/6044 [==============================] - 5s 746us/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 51/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 52/100
# 6044/6044 [==============================] - 5s 755us/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 53/100
# 6044/6044 [==============================] - 5s 746us/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 54/100
# 6044/6044 [==============================] - 5s 748us/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 55/100
# 6044/6044 [==============================] - 5s 750us/step - loss: 0.0073 - val_loss: 0.0085
# Epoch 56/100
# 6044/6044 [==============================] - 5s 749us/step - loss: 0.0073 - val_loss: 0.0069
# Epoch 57/100
# 6044/6044 [==============================] - 5s 758us/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 58/100
# 6044/6044 [==============================] - 5s 748us/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 59/100
# 6044/6044 [==============================] - 5s 753us/step - loss: 0.0071 - val_loss: 0.0077
# Epoch 60/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 61/100
# 6044/6044 [==============================] - 5s 749us/step - loss: 0.0084 - val_loss: 0.0096
# Epoch 62/100
# 6044/6044 [==============================] - 5s 756us/step - loss: 0.0094 - val_loss: 0.0091
# Epoch 63/100
# 6044/6044 [==============================] - 5s 751us/step - loss: 0.0089 - val_loss: 0.0085
# Epoch 64/100
# 6044/6044 [==============================] - 5s 754us/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 65/100
# 6044/6044 [==============================] - 5s 757us/step - loss: 0.0080 - val_loss: 0.0077
# Epoch 66/100
# 6044/6044 [==============================] - 5s 747us/step - loss: 0.0077 - val_loss: 0.0080

# %%
plt.rcParams['font.size']=13
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
def score(model,X):
 scores_ = np.square((X.values-model.predict(X))).mean(axis=1)
 return scores_

# %%
ae_train = score(AE_model, X_normal_train)
ae_test = score(AE_model, X_normal_test)
# Out:
# 7555/7555 [==============================] - 4s 479us/step
# 3238/3238 [==============================] - 2s 496us/step

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize = (15, 15))
sns.distplot(ae_train, bins=100, kde=True, color='blue', ax=ax1)
sns.distplot(ae_test, bins=100, kde=True, color='red', ax=ax2)
ax1.set_title("Train Data")
ax2.set_title("Test Data")
# Out:
# Text(0.5, 1.0, 'Test Data')

# %%
merged_data = pd.concat([X_normal_train, X_normal_test])
ae_scores = pd.DataFrame(index=merged_data.index)
ae_scores['score'] = list(np.hstack([ae_train, ae_test]))

ae_scores['anomaly'] = 0.03 < ae_scores['score']
ae_scores.head()
# Out:
#            score  anomaly
# 256522  0.005749    False
# 61799   0.009261    False
# 329656  0.004883    False
# 311807  0.007933    False
# 157183  0.023325    False

# %%
ae_scores['anomaly'].value_counts()
# Out:
# anomaly
# False    340355
# True       4978
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.hist(ae_test, bins=50)
plt.xlabel("Test MSE loss")
plt.ylabel("No of samples")
plt.axvline(0.03, color='red', linestyle='--', linewidth=1)
plt.show()

test_Y_normal = ae_test >0.03
print(" test 데이터의 불량예측 개수: ", np.sum(test_Y_normal))
# Out:
#  test 데이터의 불량예측 개수:  1559

# %%
abnormal_df =abnormal_data.copy()

abnormal_df = abnormal_df.drop(['설비 이상신호'], axis=1)

ae_abnormal = score(AE_model, abnormal_df)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
plt.figure(figsize=(8,6))
plt.hist(ae_abnormal, bins=50)
plt.xlabel("test MSE loss")
plt.ylabel("No of samples")
plt.axvline(0.03, color='red', linestyle='--', linewidth=1)
plt.show()

test_N_abnormal = ae_abnormal >0.03
print("이상점으로 예측한 개수: ", np.sum(test_N_abnormal))
# Out:
# 이상점으로 예측한 개수:  37

# %%
from sklearn.metrics import confusion_matrix

true = np.concatenate([np.zeros(len(y_normal_test)), np.ones(len(abnormal_data))])

prediction = np.concatenate([test_Y_normal, test_N_abnormal])

confusion_matrix(true, prediction)
# Out:
# array([[102041,   1559],
#        [    20,     37]], dtype=int64)

# %%
cm = confusion_matrix(true, prediction)
class_names=['정상','비정상']
fig = plt.figure(figsize=(5,4))
ax = sns.heatmap(cm, annot=True, cmap='Blues', linewidths=1, fmt="d",
 xticklabels=['정상','비정상'], yticklabels=['정상','비정상'])
ax.set(title='Confusion Matrix',
 ylabel='True label',
 xlabel='Predicted label')
plt.tight_layout()

# %%
from sklearn.metrics import classification_report
print(classification_report(true, prediction, target_names=['normal', 'abnormal']))
# Out:
#               precision    recall  f1-score   support
#
#       normal       1.00      0.98      0.99    103600
#     abnormal       0.02      0.65      0.04        57
#
#     accuracy                           0.98    103657
#    macro avg       0.51      0.82      0.52    103657
# weighted avg       1.00      0.98      0.99    103657
